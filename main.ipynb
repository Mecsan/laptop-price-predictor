# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
ld = pd.read_csv('laptop_data.csv')
ld.sample(5)
# Out:
#      Unnamed: 0 Company   TypeName  Inches                  ScreenResolution  \
# 397         397  Lenovo   Notebook    14.0       IPS Panel Full HD 1920x1080
# 780         780    Dell     Gaming    17.3       IPS Panel Full HD 1920x1080
# 578         578     MSI     Gaming    17.3                 Full HD 1920x1080
# 635         635    Asus   Notebook    15.6                 Full HD 1920x1080
# 636         636    Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                              Cpu   Ram                Memory  \
# 397   Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 780  Intel Core i7 7700HQ 2.8GHz  32GB    1TB SSD +  1TB HDD
# 578  Intel Core i7 7820HK 2.9GHz  16GB  512GB SSD +  1TB HDD
# 635  Intel Core i5 7300HQ 2.5GHz   8GB               1TB HDD
# 636   Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
#
#                           Gpu       OpSys  Weight        Price
# 397     Intel HD Graphics 620  Windows 10   1.9kg   49976.6400
# 780  Nvidia GeForce GTX 1070M  Windows 10  4.42kg  191211.2640
# 578   Nvidia GeForce GTX 1070  Windows 10  4.14kg  145401.1200
# 635   Nvidia GeForce GTX 1050  Windows 10  1.99kg   48304.7136
# 636    Intel UHD Graphics 620  Windows 10  1.23kg   99580.3200

# %%
ld.drop(columns=["Weight","OpSys","Unnamed: 0","Company","TypeName","Cpu","ScreenResolution","Inches","Gpu"],inplace=True)
ld.sample(5)
# Out:
#        Ram     Memory     Price
# 1202  16GB  512GB SSD  68464.80
# 441    4GB  256GB SSD  39906.72
# 533    4GB   32GB SSD  19660.32
# 1056   4GB  500GB HDD  26586.72
# 293    8GB  256GB SSD  97449.12

# %%
# dividing memory into 3 columns of HDD & SSD & Flash storage
memory = ld.Memory

def getHybrid(x,query):
     idx = x.find(query)
     if idx==-1:
        return 0
     ar = x[0:idx].split("+")
     ans =  ar[len(ar)-1]
     tb = ans.find("TB")
     if tb!=-1:
        val = float(ans[0:tb])
        val = val*1024
        ans = str(val)+"GB"
     gb = ans.find("GB")
     return float(ans[0:gb])


#print(memory)
hdd = np.array([getHybrid(xi,"HDD") for xi in memory])
ssd = np.array([getHybrid(xi,"SSD") for xi in memory])
flash = np.array([getHybrid(xi,"Flash") for xi in memory])
Hybrid = np.array([getHybrid(xi,"Hybrid") for xi in memory])
ld["hdd"]=hdd
ld["ssd"]=ssd
ld["flash"]=flash
ld["hybrid"]=Hybrid
ld.drop(columns=["Memory"],inplace=True)

# %%
ld['Ram'] = ld['Ram'].str.replace('GB','')
ld["Ram"]= ld["Ram"].astype('float')
ld["Price"] = ld["Price"].astype("float")
ld.sample(10)
# Out:
#       Ram       Price     hdd    ssd  flash  hybrid
# 242   8.0  47365.9200  1024.0  128.0    0.0     0.0
# 1252  6.0  30316.3200     0.0  128.0    0.0     0.0
# 357   8.0  53226.7200  1024.0    0.0    0.0     0.0
# 1002  4.0  29144.1600     0.0  128.0    0.0     0.0
# 365   8.0  20725.9200  2048.0    0.0    0.0     0.0
# 166   4.0  19367.8128  1024.0    0.0    0.0     0.0
# 303   8.0  29250.7200  2048.0    0.0    0.0     0.0
# 936   4.0  29762.2080  1024.0    0.0    0.0     0.0
# 327   8.0  55938.6720     0.0  256.0    0.0     0.0
# 1001  8.0  63349.9200     0.0  256.0    0.0     0.0

# %%
reg = linear_model.LinearRegression()
reg.fit(ld.drop(columns="Price"),ld['Price'])
ans = reg.predict([[16,1024,0,0,0]])
print(ans)
# Out:
# [75208.69577824]
# D:\data\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
